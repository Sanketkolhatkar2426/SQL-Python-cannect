# %%
# !pip install mysql-connector
# !pip install --upgrade mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector in c:\users\lenovo\anaconda3\lib\site-packages (2.2.9)
# Requirement already satisfied: mysql-connector-python in c:\users\lenovo\anaconda3\lib\site-packages (9.0.0)

# %%
import mysql.connector
import pandas as pd
import seaborn as sns

# %%
db = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password = "Sanket@12",
    database = "customer_st",
    auth_plugin = 'mysql_native_password'
)

mycursor = db.cursor()

print(db)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x000001FE88CD40E0>

# %%
mycursor.execute("select * from menu_items")

output = mycursor.fetchall()

for X in output:
    print(X)
# Out:
# (1, 'Margherita Pizza', 'Classic pizza with tomato, mozzarella, and basil', Decimal('8.99'), 'Pizza', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (2, 'Pepperoni Pizza', 'Pizza with pepperoni, tomato, and mozzarella', Decimal('9.99'), 'Pizza', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (3, 'BBQ Chicken Pizza', 'Pizza with BBQ sauce, chicken, and onions', Decimal('10.99'), 'Pizza', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (4, 'Hawaiian Pizza', 'Pizza with ham, pineapple, and cheese', Decimal('9.49'), 'Pizza', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (5, 'Veggie Pizza', 'Pizza with mushrooms, peppers, onions, and olives', Decimal('9.29'), 'Pizza', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (6, 'Spaghetti Carbonara', 'Pasta with bacon, egg, and cheese', Decimal('12.99'), 'Pasta', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (7, 'Fettuccine Alfredo', 'Pasta with creamy Alfredo sauce', Decimal('11.99'), 'Pasta', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (8, 'Lasagna', 'Layered pasta with meat, cheese, and tomato sauce', Decimal('13.99'), 'Pasta', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (9, 'Chicken Parmesan', 'Breaded chicken with marinara sauce and cheese', Decimal('14.99'), 'Main Course', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (10, 'Grilled Salmon', 'Salmon fillet with lemon and herbs', Decimal('17.99'), 'Main Course', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (11, 'Caesar Salad', 'Salad with romaine lettuce, croutons, and Caesar dressing', Decimal('7.99'), 'Salad', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (12, 'Greek Salad', 'Salad with cucumbers, tomatoes, olives, and feta cheese', Decimal('8.49'), 'Salad', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (13, 'Garden Salad', 'Mixed greens with tomatoes, cucumbers, and carrots', Decimal('6.99'), 'Salad', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (14, 'Mushroom Risotto', 'Creamy risotto with mushrooms and Parmesan cheese', Decimal('12.49'), 'Main Course', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (15, 'Beef Burger', 'Beef patty with lettuce, tomato, and cheese', Decimal('10.99'), 'Main Course', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (16, 'Cheeseburger', 'Beef patty with cheese, lettuce, and tomato', Decimal('11.49'), 'Main Course', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (17, 'Veggie Burger', 'Vegetarian patty with lettuce, tomato, and cheese', Decimal('10.49'), 'Main Course', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (18, 'Chicken Wings', 'Spicy chicken wings with dipping sauce', Decimal('9.99'), 'Appetizer', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (19, 'Mozzarella Sticks', 'Fried mozzarella sticks with marinara sauce', Decimal('7.99'), 'Appetizer', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (20, 'Onion Rings', 'Crispy onion rings with dipping sauce', Decimal('6.49'), 'Appetizer', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (21, 'Fish and Chips', 'Fried fish with French fries', Decimal('13.49'), 'Main Course', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (22, 'Shrimp Scampi', 'Shrimp in garlic butter sauce with pasta', Decimal('15.99'), 'Main Course', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (23, 'Chicken Alfredo', 'Pasta with chicken and Alfredo sauce', Decimal('14.49'), 'Pasta', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (24, 'Tiramisu', 'Italian dessert with coffee, mascarpone, and cocoa', Decimal('6.99'), 'Dessert', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (25, 'Cheesecake', 'Creamy cheesecake with a graham cracker crust', Decimal('7.49'), 'Dessert', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (26, 'Chocolate Cake', 'Rich chocolate cake with frosting', Decimal('6.49'), 'Dessert', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (27, 'Apple Pie', 'Classic apple pie with cinnamon', Decimal('5.99'), 'Dessert', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (28, 'Ice Cream Sundae', 'Vanilla ice cream with chocolate sauce and nuts', Decimal('4.99'), 'Dessert', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (29, 'Panna Cotta', 'Italian dessert with creamy custard', Decimal('5.99'), 'Dessert', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (30, 'Garlic Bread', 'Toasted bread with garlic and butter', Decimal('3.99'), 'Appetizer', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (31, 'Bruschetta', 'Grilled bread with tomato and basil', Decimal('5.49'), 'Appetizer', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (32, 'Clam Chowder', 'Creamy soup with clams and potatoes', Decimal('8.99'), 'Soup', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (33, 'Minestrone', 'Hearty Italian vegetable soup', Decimal('7.49'), 'Soup', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (34, 'Tomato Soup', 'Classic tomato soup with herbs', Decimal('6.99'), 'Soup', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (35, 'French Onion Soup', 'Onion soup with melted cheese and croutons', Decimal('8.49'), 'Soup', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (36, 'Roast Chicken', 'Roasted chicken with herbs and vegetables', Decimal('16.99'), 'Main Course', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (37, 'Steak Frites', 'Grilled steak with French fries', Decimal('18.99'), 'Main Course', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (38, 'Pork Chops', 'Grilled pork chops with applesauce', Decimal('15.49'), 'Main Course', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (39, 'Lobster Bisque', 'Rich and creamy lobster soup', Decimal('9.99'), 'Soup', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (40, 'Caesar Wrap', 'Caesar salad in a tortilla wrap', Decimal('8.99'), 'Main Course', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (41, 'Club Sandwich', 'Sandwich with turkey, bacon, lettuce, and tomato', Decimal('9.99'), 'Main Course', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (42, 'BLT Sandwich', 'Bacon, lettuce, and tomato sandwich', Decimal('7.99'), 'Main Course', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (43, 'Turkey Sandwich', 'Turkey breast with lettuce and mayo', Decimal('8.49'), 'Main Course', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (44, 'Eggplant Parmesan', 'Baked eggplant with marinara and cheese', Decimal('13.99'), 'Main Course', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (45, 'Grilled Cheese Sandwich', 'Toasted sandwich with melted cheese', Decimal('6.49'), 'Main Course', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (46, 'Pasta Primavera', 'Pasta with fresh vegetables and olive oil', Decimal('11.49'), 'Pasta', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (47, 'Baked Ziti', 'Pasta baked with tomato sauce and cheese', Decimal('12.49'), 'Pasta', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))
# (48, 'Chicken Caesar Salad', 'Caesar salad topped with grilled chicken', Decimal('9.49'), 'Salad', 1, datetime.datetime(2024, 8, 17, 13, 45, 55))

# %%
query = "select * from menu_items"

df = pd.read_sql(query,db)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4140\975409482.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query,db)

# %%
df.head(20)
# Out:
#     id            item_name  \
# 0    1     Margherita Pizza
# 1    2      Pepperoni Pizza
# 2    3    BBQ Chicken Pizza
# 3    4       Hawaiian Pizza
# 4    5         Veggie Pizza
# 5    6  Spaghetti Carbonara
# 6    7   Fettuccine Alfredo
# 7    8              Lasagna
# 8    9     Chicken Parmesan
# 9   10       Grilled Salmon
# 10  11         Caesar Salad
# 11  12          Greek Salad
# 12  13         Garden Salad
# 13  14     Mushroom Risotto
# 14  15          Beef Burger
# 15  16         Cheeseburger
# 16  17        Veggie Burger
# 17  18        Chicken Wings
# 18  19    Mozzarella Sticks
# 19  20          Onion Rings
#
#                                           description  price     category  \
# 0    Classic pizza with tomato, mozzarella, and basil   8.99        Pizza
# 1        Pizza with pepperoni, tomato, and mozzarella   9.99        Pizza
# 2           Pizza with BBQ sauce, chicken, and onions  10.99        Pizza
# 3               Pizza with ham, pineapple, and cheese   9.49        Pizza
# 4   Pizza with mushrooms, peppers, onions, and olives   9.29        Pizza
# 5                   Pasta with bacon, egg, and cheese  12.99        Pasta
# 6                     Pasta with creamy Alfredo sauce  11.99        Pasta
# 7   Layered pasta with meat, cheese, and tomato sauce  13.99        Pasta
# 8      Breaded chicken with marinara sauce and cheese  14.99  Main Course
# 9                  Salmon fillet with lemon and herbs  17.99  Main Course
# 10  Salad with romaine lettuce, croutons, and Caes...   7.99        Salad
# 11  Salad with cucumbers, tomatoes, olives, and fe...   8.49        Salad
# 12  Mixed greens with tomatoes, cucumbers, and car...   6.99        Salad
# 13  Creamy risotto with mushrooms and Parmesan cheese  12.49  Main Course
# 14        Beef patty with lettuce, tomato, and cheese  10.99  Main Course
# 15        Beef patty with cheese, lettuce, and tomato  11.49  Main Course
# 16  Vegetarian patty with lettuce, tomato, and cheese  10.49  Main Course
# 17             Spicy chicken wings with dipping sauce   9.99    Appetizer
# 18        Fried mozzarella sticks with marinara sauce   7.99    Appetizer
# 19              Crispy onion rings with dipping sauce   6.49    Appetizer
#
#     availability          created_at
# 0              1 2024-08-17 13:45:55
# 1              1 2024-08-17 13:45:55
# 2              1 2024-08-17 13:45:55
# 3              1 2024-08-17 13:45:55
# 4              1 2024-08-17 13:45:55
# 5              1 2024-08-17 13:45:55
# 6              1 2024-08-17 13:45:55
# 7              1 2024-08-17 13:45:55
# 8              1 2024-08-17 13:45:55
# 9              1 2024-08-17 13:45:55
# 10             1 2024-08-17 13:45:55
# 11             1 2024-08-17 13:45:55
# 12             1 2024-08-17 13:45:55
# 13             1 2024-08-17 13:45:55
# 14             1 2024-08-17 13:45:55
# 15             1 2024-08-17 13:45:55
# 16             1 2024-08-17 13:45:55
# 17             1 2024-08-17 13:45:55
# 18             1 2024-08-17 13:45:55
# 19             1 2024-08-17 13:45:55

# %%
df.tail(10)
# Out:
#     id                item_name  \
# 38  39           Lobster Bisque
# 39  40              Caesar Wrap
# 40  41            Club Sandwich
# 41  42             BLT Sandwich
# 42  43          Turkey Sandwich
# 43  44        Eggplant Parmesan
# 44  45  Grilled Cheese Sandwich
# 45  46          Pasta Primavera
# 46  47               Baked Ziti
# 47  48     Chicken Caesar Salad
#
#                                          description  price     category  \
# 38                      Rich and creamy lobster soup   9.99         Soup
# 39                   Caesar salad in a tortilla wrap   8.99  Main Course
# 40  Sandwich with turkey, bacon, lettuce, and tomato   9.99  Main Course
# 41               Bacon, lettuce, and tomato sandwich   7.99  Main Course
# 42               Turkey breast with lettuce and mayo   8.49  Main Course
# 43           Baked eggplant with marinara and cheese  13.99  Main Course
# 44               Toasted sandwich with melted cheese   6.49  Main Course
# 45         Pasta with fresh vegetables and olive oil  11.49        Pasta
# 46          Pasta baked with tomato sauce and cheese  12.49        Pasta
# 47          Caesar salad topped with grilled chicken   9.49        Salad
#
#     availability          created_at
# 38             1 2024-08-17 13:45:55
# 39             1 2024-08-17 13:45:55
# 40             1 2024-08-17 13:45:55
# 41             1 2024-08-17 13:45:55
# 42             1 2024-08-17 13:45:55
# 43             1 2024-08-17 13:45:55
# 44             1 2024-08-17 13:45:55
# 45             1 2024-08-17 13:45:55
# 46             1 2024-08-17 13:45:55
# 47             1 2024-08-17 13:45:55

# %%
df.isna().sum()
# Out:
# id              0
# item_name       0
# description     0
# price           0
# category        0
# availability    0
# created_at      0
# dtype: int64

# %%
df.isnull()
# Out:
#        id  item_name  description  price  category  availability  created_at
# 0   False      False        False  False     False         False       False
# 1   False      False        False  False     False         False       False
# 2   False      False        False  False     False         False       False
# 3   False      False        False  False     False         False       False
# 4   False      False        False  False     False         False       False
# 5   False      False        False  False     False         False       False
# 6   False      False        False  False     False         False       False
# 7   False      False        False  False     False         False       False
# 8   False      False        False  False     False         False       False
# 9   False      False        False  False     False         False       False
# 10  False      False        False  False     False         False       False
# 11  False      False        False  False     False         False       False
# 12  False      False        False  False     False         False       False
# 13  False      False        False  False     False         False       False
# 14  False      False        False  False     False         False       False
# 15  False      False        False  False     False         False       False
# 16  False      False        False  False     False         False       False
# 17  False      False        False  False     False         False       False
# 18  False      False        False  False     False         False       False
# 19  False      False        False  False     False         False       False
# 20  False      False        False  False     False         False       False
# 21  False      False        False  False     False         False       False
# 22  False      False        False  False     False         False       False
# 23  False      False        False  False     False         False       False
# 24  False      False        False  False     False         False       False
# 25  False      False        False  False     False         False       False
# 26  False      False        False  False     False         False       False
# 27  False      False        False  False     False         False       False
# 28  False      False        False  False     False         False       False
# 29  False      False        False  False     False         False       False
# 30  False      False        False  False     False         False       False
# 31  False      False        False  False     False         False       False
# 32  False      False        False  False     False         False       False
# 33  False      False        False  False     False         False       False
# 34  False      False        False  False     False         False       False
# 35  False      False        False  False     False         False       False
# 36  False      False        False  False     False         False       False
# 37  False      False        False  False     False         False       False
# 38  False      False        False  False     False         False       False
# 39  False      False        False  False     False         False       False
# 40  False      False        False  False     False         False       False
# 41  False      False        False  False     False         False       False
# 42  False      False        False  False     False         False       False
# 43  False      False        False  False     False         False       False
# 44  False      False        False  False     False         False       False
# 45  False      False        False  False     False         False       False
# 46  False      False        False  False     False         False       False
# 47  False      False        False  False     False         False       False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            48 non-null     int64
#  1   item_name     48 non-null     object
#  2   description   48 non-null     object
#  3   price         48 non-null     float64
#  4   category      48 non-null     object
#  5   availability  48 non-null     int64
#  6   created_at    48 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 2.8+ KB

# %%
df[df.index==4]
# Out:
#    id     item_name                                        description  price  \
# 4   5  Veggie Pizza  Pizza with mushrooms, peppers, onions, and olives   9.29
#
#   category  availability          created_at
# 4    Pizza             1 2024-08-17 13:45:55

# %%
df[df.index.isin(range(2,10))]
# Out:
#    id            item_name                                        description  \
# 2   3    BBQ Chicken Pizza          Pizza with BBQ sauce, chicken, and onions
# 3   4       Hawaiian Pizza              Pizza with ham, pineapple, and cheese
# 4   5         Veggie Pizza  Pizza with mushrooms, peppers, onions, and olives
# 5   6  Spaghetti Carbonara                  Pasta with bacon, egg, and cheese
# 6   7   Fettuccine Alfredo                    Pasta with creamy Alfredo sauce
# 7   8              Lasagna  Layered pasta with meat, cheese, and tomato sauce
# 8   9     Chicken Parmesan     Breaded chicken with marinara sauce and cheese
# 9  10       Grilled Salmon                 Salmon fillet with lemon and herbs
#
#    price     category  availability          created_at
# 2  10.99        Pizza             1 2024-08-17 13:45:55
# 3   9.49        Pizza             1 2024-08-17 13:45:55
# 4   9.29        Pizza             1 2024-08-17 13:45:55
# 5  12.99        Pasta             1 2024-08-17 13:45:55
# 6  11.99        Pasta             1 2024-08-17 13:45:55
# 7  13.99        Pasta             1 2024-08-17 13:45:55
# 8  14.99  Main Course             1 2024-08-17 13:45:55
# 9  17.99  Main Course             1 2024-08-17 13:45:55

# %%
df.loc[5]
# Out:
# id                                              6
# item_name                     Spaghetti Carbonara
# description     Pasta with bacon, egg, and cheese
# price                                       12.99
# category                                    Pasta
# availability                                    1
# created_at                    2024-08-17 13:45:55
# Name: 5, dtype: object

# %%
df.iloc[6]
# Out:
# id                                            7
# item_name                    Fettuccine Alfredo
# description     Pasta with creamy Alfredo sauce
# price                                     11.99
# category                                  Pasta
# availability                                  1
# created_at                  2024-08-17 13:45:55
# Name: 6, dtype: object

# %%
df.iloc[2:10]
# Out:
#    id            item_name                                        description  \
# 2   3    BBQ Chicken Pizza          Pizza with BBQ sauce, chicken, and onions
# 3   4       Hawaiian Pizza              Pizza with ham, pineapple, and cheese
# 4   5         Veggie Pizza  Pizza with mushrooms, peppers, onions, and olives
# 5   6  Spaghetti Carbonara                  Pasta with bacon, egg, and cheese
# 6   7   Fettuccine Alfredo                    Pasta with creamy Alfredo sauce
# 7   8              Lasagna  Layered pasta with meat, cheese, and tomato sauce
# 8   9     Chicken Parmesan     Breaded chicken with marinara sauce and cheese
# 9  10       Grilled Salmon                 Salmon fillet with lemon and herbs
#
#    price     category  availability          created_at
# 2  10.99        Pizza             1 2024-08-17 13:45:55
# 3   9.49        Pizza             1 2024-08-17 13:45:55
# 4   9.29        Pizza             1 2024-08-17 13:45:55
# 5  12.99        Pasta             1 2024-08-17 13:45:55
# 6  11.99        Pasta             1 2024-08-17 13:45:55
# 7  13.99        Pasta             1 2024-08-17 13:45:55
# 8  14.99  Main Course             1 2024-08-17 13:45:55
# 9  17.99  Main Course             1 2024-08-17 13:45:55

# %%
df.mode()
# Out:
#     id                item_name  \
# 0    1                Apple Pie
# 1    2        BBQ Chicken Pizza
# 2    3             BLT Sandwich
# 3    4               Baked Ziti
# 4    5              Beef Burger
# 5    6               Bruschetta
# 6    7             Caesar Salad
# 7    8              Caesar Wrap
# 8    9             Cheeseburger
# 9   10               Cheesecake
# 10  11          Chicken Alfredo
# 11  12     Chicken Caesar Salad
# 12  13         Chicken Parmesan
# 13  14            Chicken Wings
# 14  15           Chocolate Cake
# 15  16             Clam Chowder
# 16  17            Club Sandwich
# 17  18        Eggplant Parmesan
# 18  19       Fettuccine Alfredo
# 19  20           Fish and Chips
# 20  21        French Onion Soup
# 21  22             Garden Salad
# 22  23             Garlic Bread
# 23  24              Greek Salad
# 24  25  Grilled Cheese Sandwich
# 25  26           Grilled Salmon
# 26  27           Hawaiian Pizza
# 27  28         Ice Cream Sundae
# 28  29                  Lasagna
# 29  30           Lobster Bisque
# 30  31         Margherita Pizza
# 31  32               Minestrone
# 32  33        Mozzarella Sticks
# 33  34         Mushroom Risotto
# 34  35              Onion Rings
# 35  36              Panna Cotta
# 36  37          Pasta Primavera
# 37  38          Pepperoni Pizza
# 38  39               Pork Chops
# 39  40            Roast Chicken
# 40  41            Shrimp Scampi
# 41  42      Spaghetti Carbonara
# 42  43             Steak Frites
# 43  44                 Tiramisu
# 44  45              Tomato Soup
# 45  46          Turkey Sandwich
# 46  47            Veggie Burger
# 47  48             Veggie Pizza
#
#                                           description  price     category  \
# 0                 Bacon, lettuce, and tomato sandwich   9.99  Main Course
# 1             Baked eggplant with marinara and cheese    NaN          NaN
# 2         Beef patty with cheese, lettuce, and tomato    NaN          NaN
# 3         Beef patty with lettuce, tomato, and cheese    NaN          NaN
# 4      Breaded chicken with marinara sauce and cheese    NaN          NaN
# 5                     Caesar salad in a tortilla wrap    NaN          NaN
# 6            Caesar salad topped with grilled chicken    NaN          NaN
# 7                     Classic apple pie with cinnamon    NaN          NaN
# 8    Classic pizza with tomato, mozzarella, and basil    NaN          NaN
# 9                      Classic tomato soup with herbs    NaN          NaN
# 10      Creamy cheesecake with a graham cracker crust    NaN          NaN
# 11  Creamy risotto with mushrooms and Parmesan cheese    NaN          NaN
# 12                Creamy soup with clams and potatoes    NaN          NaN
# 13              Crispy onion rings with dipping sauce    NaN          NaN
# 14                       Fried fish with French fries    NaN          NaN
# 15        Fried mozzarella sticks with marinara sauce    NaN          NaN
# 16                Grilled bread with tomato and basil    NaN          NaN
# 17                 Grilled pork chops with applesauce    NaN          NaN
# 18                    Grilled steak with French fries    NaN          NaN
# 19                      Hearty Italian vegetable soup    NaN          NaN
# 20  Italian dessert with coffee, mascarpone, and c...    NaN          NaN
# 21                Italian dessert with creamy custard    NaN          NaN
# 22  Layered pasta with meat, cheese, and tomato sauce    NaN          NaN
# 23  Mixed greens with tomatoes, cucumbers, and car...    NaN          NaN
# 24         Onion soup with melted cheese and croutons    NaN          NaN
# 25           Pasta baked with tomato sauce and cheese    NaN          NaN
# 26                  Pasta with bacon, egg, and cheese    NaN          NaN
# 27               Pasta with chicken and Alfredo sauce    NaN          NaN
# 28                    Pasta with creamy Alfredo sauce    NaN          NaN
# 29          Pasta with fresh vegetables and olive oil    NaN          NaN
# 30          Pizza with BBQ sauce, chicken, and onions    NaN          NaN
# 31              Pizza with ham, pineapple, and cheese    NaN          NaN
# 32  Pizza with mushrooms, peppers, onions, and olives    NaN          NaN
# 33       Pizza with pepperoni, tomato, and mozzarella    NaN          NaN
# 34                       Rich and creamy lobster soup    NaN          NaN
# 35                  Rich chocolate cake with frosting    NaN          NaN
# 36          Roasted chicken with herbs and vegetables    NaN          NaN
# 37  Salad with cucumbers, tomatoes, olives, and fe...    NaN          NaN
# 38  Salad with romaine lettuce, croutons, and Caes...    NaN          NaN
# 39                 Salmon fillet with lemon and herbs    NaN          NaN
# 40   Sandwich with turkey, bacon, lettuce, and tomato    NaN          NaN
# 41           Shrimp in garlic butter sauce with pasta    NaN          NaN
# 42             Spicy chicken wings with dipping sauce    NaN          NaN
# 43               Toasted bread with garlic and butter    NaN          NaN
# 44                Toasted sandwich with melted cheese    NaN          NaN
# 45                Turkey breast with lettuce and mayo    NaN          NaN
# 46    Vanilla ice cream with chocolate sauce and nuts    NaN          NaN
# 47  Vegetarian patty with lettuce, tomato, and cheese    NaN          NaN
#
#     availability          created_at
# 0            1.0 2024-08-17 13:45:55
# 1            NaN                 NaT
# 2            NaN                 NaT
# 3            NaN                 NaT
# 4            NaN                 NaT
# 5            NaN                 NaT
# 6            NaN                 NaT
# 7            NaN                 NaT
# 8            NaN                 NaT
# 9            NaN                 NaT
# 10           NaN                 NaT
# 11           NaN                 NaT
# 12           NaN                 NaT
# 13           NaN                 NaT
# 14           NaN                 NaT
# 15           NaN                 NaT
# 16           NaN                 NaT
# 17           NaN                 NaT
# 18           NaN                 NaT
# 19           NaN                 NaT
# 20           NaN                 NaT
# 21           NaN                 NaT
# 22           NaN                 NaT
# 23           NaN                 NaT
# 24           NaN                 NaT
# 25           NaN                 NaT
# 26           NaN                 NaT
# 27           NaN                 NaT
# 28           NaN                 NaT
# 29           NaN                 NaT
# 30           NaN                 NaT
# 31           NaN                 NaT
# 32           NaN                 NaT
# 33           NaN                 NaT
# 34           NaN                 NaT
# 35           NaN                 NaT
# 36           NaN                 NaT
# 37           NaN                 NaT
# 38           NaN                 NaT
# 39           NaN                 NaT
# 40           NaN                 NaT
# 41           NaN                 NaT
# 42           NaN                 NaT
# 43           NaN                 NaT
# 44           NaN                 NaT
# 45           NaN                 NaT
# 46           NaN                 NaT
# 47           NaN                 NaT

# %%
df.median()

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.pie(y='price',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='price'>

# %%
df.plot.barh()
# Out:
# <Axes: >

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot()
# Out:
# <Axes: >
